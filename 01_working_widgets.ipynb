# %%
dbutils.fs.put("/Volumes/bizmetric_databricks_learning/default/sep_2026_training_aaisha/emp.txt", "empid|name|salary")

# %%
df = spark.read.csv("/Volumes/bizmetric_databricks_learning/default/sep_2026_training/F1_project/races.csv")
display(df)

# %%
dbutils.fs.put("/Volumes/bizmetric_databricks_learning/default/sep_2026_training_aaisha/emp.txt", "empid|name|salary\n1|Nishad|19000", overwrite=True)

# %%
dbutils.widgets.text("file_path", " ", "Enter file path")
file_path = dbutils.widgets.get("file_path")

# %%
dbutils.widgets.dropdown("environment", "dev",
    ['dev','test','prod'],
    "select environment")
